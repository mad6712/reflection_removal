# %%
import torch
import torch.nn as nn
import torchvision.models as models
import os
from PIL import Image
from torchvision import transforms
import albumentations as A
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Image Augmentation Pipeline (Albumentations)
# --------------------------------------------
# This pipeline is designed to increase dataset variability and improve model generalization,
# especially for tasks like reflection removal. Each transformation is applied with a given
# probability and can introduce randomness in orientation, brightness, contrast, and image clarity.
#
# Transformations used:
# - HorizontalFlip (p=0.9): Flip image left ↔ right
# - VerticalFlip (p=0.9): Flip image top ↕ bottom
# - RandomRotate90 (p=0.9): Rotate image by a random multiple of 90° (0, 90, 180, 270)
# - Rotate (limit=45, p=0.9): Rotate image randomly within ±45°
# - RandomBrightnessContrast (p=0.5): Randomly tweak brightness and contrast
# - Blur (blur_limit=7, p=0.3): Apply random blur to simulate camera or motion blur
# - Resize (512x512): Resize image to a fixed size for model input consistency
#
# These augmentations are randomized and applied during training to improve robustness
# against visual variability like lighting, angle, and slight distortions.


augmentations = A.Compose([
    A.HorizontalFlip(p=0.9),
    A.VerticalFlip(p=0.9),
    A.RandomRotate90(p=0.9),
    A.Rotate(limit=45, p=0.9),
    A.RandomBrightnessContrast(p=0.6),
    A.Blur(blur_limit=7, p=0.4),
    A.Resize(512, 512),
])


# List of directories containing paired input/target subdirectories
dataset_dirs = [r"/home/madhur/Projects/reflection_removal/model/dataset/DSLR/unaligned_test50", 
                r"/home/madhur/Projects/reflection_removal/model/dataset/DSLR/unaligned_train250",
                r"/home/madhur/Projects/reflection_removal/model/dataset/Smartphone/unaligned150"               
                ]  # Add paths to your directories here

# Global output directories
output_input_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_blended"
output_target_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_transmission_layer"

# Ensure output directories exist
os.makedirs(output_input_dir, exist_ok=True)
os.makedirs(output_target_dir, exist_ok=True)

# Function to augment and save images
def augment_and_save(input_path, target_path, output_input_dir, output_target_dir, new_name):
    input_image = cv2.imread(input_path)
    target_image = cv2.imread(target_path)

    # Apply augmentations
    augmented = augmentations(image=input_image, mask=target_image)
    augmented_input = augmented['image']
    augmented_target = augmented['mask']

    # Save augmented images
    cv2.imwrite(os.path.join(output_input_dir, new_name), augmented_input)
    cv2.imwrite(os.path.join(output_target_dir, new_name), augmented_target)

# Process each dataset directory
image_counter = 0  # Counter to ensure unique filenames across all directories

for dataset_dir in dataset_dirs:
    input_dir = os.path.join(dataset_dir, "blended")
    target_dir = os.path.join(dataset_dir, "transmission_layer")

    # Process each pair of input/target images
    input_files = sorted(os.listdir(input_dir))
    target_files = sorted(os.listdir(target_dir))

    for input_file, target_file in zip(input_files, target_files):
        # Ensure input and target have the same name
        input_path = os.path.join(input_dir, input_file)
        target_path = os.path.join(target_dir, target_file)

        # Perform 3 augmentations per image
        for i in range(5):
            new_name = f"aug_image_{image_counter:04d}.jpg"  # Unique name with a zero-padded counter
            augment_and_save(input_path, target_path, output_input_dir, output_target_dir, new_name)
            image_counter += 1

print("Augmentation completed. All images are stored in 'aug_blended' and 'aug_transmission_layer'.")
# Out:
# Augmentation completed. All images are stored in 'aug_blended' and 'aug_transmission_layer'.

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.skip_connection = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.skip_connection = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        identity = self.skip_connection(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += identity
        out = self.relu(out)
        return out

# ResNet-style Encoder and Decoder
class ReflectionRemovalNet(nn.Module):
    def __init__(self):
        super(ReflectionRemovalNet, self).__init__()

        self.encoder = nn.Sequential(
            ResidualBlock(3, 64, stride=1),
            ResidualBlock(64, 128, stride=2),
            ResidualBlock(128, 256, stride=2)
        )
        
        # Bottleneck
        self.bottleneck = nn.Sequential(
            ResidualBlock(256, 256, stride=1)
        )
        
        self.decoder = nn.Sequential(
            ResidualBlock(256, 128, stride=1),
            nn.ConvTranspose2d(128, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(inplace=True),
            ResidualBlock(128, 64, stride=1),
            nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()  
        )
    
    def forward(self, x):
        enc = self.encoder(x)
        bottleneck = self.bottleneck(enc)
        dec = self.decoder(bottleneck)
        return dec

class PerceptualLoss(nn.Module):
    def __init__(self, path=r"/home/madhur/Projects/reflection_removal/model/models/mobilenet_v2-b0353104.pth"):
        super(PerceptualLoss, self).__init__()
        
        mobilenet = models.mobilenet_v2(pretrained=True)
        self.features = mobilenet.features
        self.layers = nn.Sequential(*list(self.features.children())[:15]).eval()
    
        for param in self.layers.parameters():
            param.requires_grad = False

    def forward(self, input, target):
        input_features = self.layers(input)
        target_features = self.layers(target)
        return nn.functional.l1_loss(input_features, target_features)


# gives pixel level accuracy
class ReconstructionLoss(nn.Module):
    def __init__(self, loss_type='l1'):
        super(ReconstructionLoss, self).__init__()
        if loss_type == 'l1':
            self.loss_fn = nn.L1Loss()
        elif loss_type == 'l2':
            self.loss_fn = nn.MSELoss()

    def forward(self, predicted, target):
        return self.loss_fn(predicted, target)

# %%
class ReflectionDataset(torch.utils.data.Dataset):
    def __init__(self, reflected_dir, clear_dir, transform=None):
        self.reflected_files = sorted(os.listdir(reflected_dir))
        self.clear_files = sorted(os.listdir(clear_dir))
        self.reflected_dir = reflected_dir
        self.clear_dir = clear_dir
        self.transform = transform

    def __len__(self):
        return len(self.reflected_files)

    def __getitem__(self, idx):
        reflected_image = Image.open(os.path.join(self.reflected_dir, self.reflected_files[idx])).convert('RGB')
        clear_image = Image.open(os.path.join(self.clear_dir, self.clear_files[idx])).convert('RGB')

        if self.transform:
            reflected_image = self.transform(reflected_image)
            clear_image = self.transform(clear_image)

        return {'input': reflected_image, 'target': clear_image}

# Data Preprocessing
def get_dataloader(reflected_dir, clear_dir, batch_size=16):
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor()
    ])

    dataset = ReflectionDataset(reflected_dir=reflected_dir, clear_dir=clear_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return dataloader

# %%
def train_model(
    model, dataloader, device, num_epochs=25, learning_rate=1e-4, output_dir="/home/madhur/Projects/reflection_removal/model/models/"
):
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # defining all the functions
    perceptual_loss_fn = PerceptualLoss().to(device)
    mse_loss_fn = nn.MSELoss()  # MSE Loss
    reconstruction_loss_fn = nn.L1Loss()  

    model = model.to(device)

    for epoch in range(num_epochs):
        if epoch > 300:
            for param_group in optimizer.param_groups:
                param_group['lr'] = learning_rate
            
        model.train()
        running_loss = 0.0
        
        for batch in dataloader:
            inputs, targets = batch['input'].to(device), batch['target'].to(device)

            # Forward pass
            outputs = model(inputs)
            mse_loss = mse_loss_fn(outputs, targets)  
            perceptual_loss = perceptual_loss_fn(outputs, targets) 
            reconstruction_loss = reconstruction_loss_fn(outputs, targets)  
            
            loss = mse_loss + 0.5 * perceptual_loss + 0.5 * reconstruction_loss #sum all hte losses
            
            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}")

        if (epoch + 1) % 50 == 0:  # checkpointing
            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
            torch.save(model.state_dict(), os.path.join(output_dir, f"model_epoch_{epoch+1}.pth"))
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    torch.save(model.state_dict(), os.path.join(output_dir, "new_model_final.pth"))
    print("Training complete. Model saved.")

# %%
if __name__ == "__main__":
    reflected_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_blended" # train images that have reflections
    clear_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_blended" # train images that have no reflections
    output_dir = r"/home/madhur/Projects/reflection_removal/model/models" # dir to store the model

    os.makedirs(output_dir, exist_ok=True)

    batch_size = 16
    num_epochs = 100
    learning_rate = 1e-3

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataloader = get_dataloader(reflected_dir, clear_dir, batch_size)
    model = ReflectionRemovalNet()

    train_model(model, dataloader, device, num_epochs, learning_rate, output_dir)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 16
#      13 dataloader = get_dataloader(reflected_dir, clear_dir, batch_size)
#      14 model = ReflectionRemovalNet()
# ---> 16 train_model(model, dataloader, device, num_epochs, learning_rate, output_dir)
#
# Cell In[5], line 25, in train_model(model, dataloader, device, num_epochs, learning_rate, output_dir)
#      22 inputs, targets = batch['input'].to(device), batch['target'].to(device)
#      24 # Forward pass
# ---> 25 outputs = model(inputs)
#      26 mse_loss = mse_loss_fn(outputs, targets)
#      27 perceptual_loss = perceptual_loss_fn(outputs, targets)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[3], line 55, in ReflectionRemovalNet.forward(self, x)
#      54 def forward(self, x):
# ---> 55     enc = self.encoder(x)
#      56     bottleneck = self.bottleneck(enc)
#      57     dec = self.decoder(bottleneck)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[3], line 17, in ResidualBlock.forward(self, x)
#      16 def forward(self, x):
# ---> 17     identity = self.skip_connection(x)
#      18     out = self.conv1(x)
#      19     out = self.bn1(out)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/reflection_model/lib/python3.10/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 256.00 MiB. GPU 0 has a total capacity of 3.63 GiB of which 129.31 MiB is free. Including non-PyTorch memory, this process has 3.50 GiB memory in use. Of the allocated memory 3.16 GiB is allocated by PyTorch, and 279.58 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
def load_model(model_path, device):
    model = ReflectionRemovalNet()  
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model

def process_image(image_path, transform, device):

    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0) # to correct the dimension
    return image.to(device)

def save_output_image(output_tensor, save_path):
    output_image = output_tensor.squeeze(0).cpu().detach()
    output_image = transforms.ToPILImage()(output_image)
    output_image.save(save_path)

def test_model(model_path, input_dir, output_dir, device):
    os.makedirs(output_dir, exist_ok=True)
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor()
    ])

    model = load_model(model_path, device) 

    input_images = sorted(os.listdir(input_dir))
    for img_name in input_images:
        input_path = os.path.join(input_dir, img_name)
        output_path = os.path.join(output_dir, img_name)

        # check if image files
        if not img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            print(f"Skipping non-image file: {img_name}")
            continue

        input_tensor = process_image(input_path, transform, device)

        # generating output
        with torch.no_grad():
            output_tensor = model(input_tensor)

        save_output_image(output_tensor, output_path)
        print(f"Processed {img_name} and saved to {output_path}")

if __name__ == "__main__":
    model_path = r"/home/madhur/Projects/reflection_removal/model/models/new_model_final.pth"  # path to the trained model
    input_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_blended"  # Folder containing test reflected images
    output_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/predicted"  # Folder to save output images

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    test_model(model_path, input_dir, output_dir, device)
# Out:
# /tmp/ipykernel_121530/4248337273.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Processed aug_image_0000.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0000.jpg
# Processed aug_image_0001.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_
jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0077.jpg
# Processed aug_image_0078.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0078.jpg
# Processed aug_image_0079.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0079.jpg
# Processed aug_image_0080.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0080.jpg
# Processed aug_image_0081.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0081.jpg
# Processed aug_image_0082.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0082.jpg
# Processed aug_image_0083.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0083.jpg
# Processed aug_image_0084.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0084.jpg
# Processed aug_image_0085.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0085.jpg
# Processed aug_image_0086.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0086.jpg
# Processed aug_image_0087.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0087.jpg
# Processed aug_image_0088.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0088.jpg
# Processed aug_image_0089.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0089.jpg
# Processed aug_image_0090.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0090.jpg
# Processed aug_image_0091.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0091.jpg
# Processed aug_image_0092.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0092.jpg
# Processed aug_image_0093.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0093.jpg
# Processed aug_image_0094.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0094.jpg
# Processed aug_image_0095.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0095.jpg
# Processed aug_image_0096.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0096.jpg
# Processed aug_image_0097.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0097.jpg
# Processed aug_image_0098.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0098.jpg
# Processed aug_image_0099.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0099.jpg
# Processed aug_image_0100.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0100.jpg
# Processed aug_image_0101.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0101.jpg
# Processed aug_image_0102.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0102.jpg
# Processed aug_image_0103.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0103.jpg
# Processed aug_image_0104.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0104.jpg
# Processed aug_image_0105.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0105.jpg
# Processed aug_image_0106.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0106.jpg
# Processed aug_image_0107.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0107.jpg
# Processed aug_image_0108.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0108.jpg
# Processed aug_image_0109.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0109.jpg
# Processed aug_image_0110.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0110.jpg
# Processed aug_image_0111.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0111.jpg
# Processed aug_image_0112.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0112.jpg
# Processed aug_image_0113.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0113.jpg
# Processed aug_image_0114.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0114.jpg
# Processed aug_image_0115.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0115.jpg
# Processed aug_image_0116.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0116.jpg
# Processed aug_image_0117.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0117.jpg
# Processed aug_image_0118.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0118.jpg
# Processed aug_image_0119.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0119.jpg
# Processed aug_image_0120.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0120.jpg
# Processed aug_image_0121.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0121.jpg
# Processed aug_image_0122.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0122.jpg
# Processed aug_image_0123.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0123.jpg
# Processed aug_image_0124.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0124.jpg
# Processed aug_image_0125.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0125.jpg
# Processed aug_image_0126.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0126.jpg
# Processed aug_image_0127.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0127.jpg
# Processed aug_image_0128.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0128.jpg
# Processed aug_image_0129.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0129.jpg
# Processed aug_image_0130.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0130.jpg
# Processed aug_image_0131.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0131.jpg
# Processed aug_image_0132.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0132.jpg
# Processed aug_image_0133.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0133.jpg
# Processed aug_image_0134.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0134.jpg
# Processed aug_image_0135.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0135.jpg
# Processed aug_image_0136.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0136.jpg
# Processed aug_image_0137.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0137.jpg
# Processed aug_image_0138.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0138.jpg
# Processed aug_image_0139.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0139.jpg
# Processed aug_image_0140.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0140.jpg
# Processed aug_image_0141.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0141.jpg
# Processed aug_image_0142.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0142.jpg
# Processed aug_image_0143.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0143.jpg
# Processed aug_image_0144.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0144.jpg
# Processed aug_image_0145.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0145.jpg
# Processed aug_image_0146.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0146.jpg
# Processed aug_image_0147.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0147.jpg
# Processed aug_image_0148.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0148.jpg
# Processed aug_image_0149.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0149.jpg
# Processed aug_image_0150.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0150.jpg
# Processed aug_image_0151.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0151.jpg
# Processed aug_image_0152.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0152.jpg
# Processed aug_image_0153.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0153.jpg
# Processed aug_image_0154.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0154.jpg
# Processed aug_image_0155.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0155.jpg
# Processed aug_image_0156.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0156.jpg
# Processed aug_image_0157.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0157.jpg
# Processed aug_image_0158.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0158.jpg
# Processed aug_image_0159.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0159.jpg
# Processed aug_image_0160.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0160.jpg
# Processed aug_image_0161.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0161.jpg
# Processed aug_image_0162.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0162.jpg
# Processed aug_image_0163.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0163.jpg
# Processed aug_image_0164.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0164.jpg
# Processed aug_image_0165.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0165.jpg
# Processed aug_image_0166.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0166.jpg
# Processed aug_image_0167.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0167.jpg
# Processed aug_image_0168.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0168.jpg
# Processed aug_image_0169.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0169.jpg
# Processed aug_image_0170.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0170.jpg
# Processed aug_image_0171.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0171.jpg
# Processed aug_image_0172.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0172.jpg
# Processed aug_image_0173.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0173.jpg
# Processed aug_image_0174.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0174.jpg
# Processed aug_image_0175.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0175.jpg
# Processed aug_image_0176.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0176.jpg
# Processed aug_image_0177.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0177.jpg
# Processed aug_image_0178.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0178.jpg
# Processed aug_image_0179.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0179.jpg
# Processed aug_image_0180.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0180.jpg
# Processed aug_image_0181.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0181.jpg
# Processed aug_image_0182.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0182.jpg
# Processed aug_image_0183.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0183.jpg
# Processed aug_image_0184.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0184.jpg
# Processed aug_image_0185.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0185.jpg
# Processed aug_image_0186.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0186.jpg
# Processed aug_image_0187.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0187.jpg
# Processed aug_image_0188.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0188.jpg
# Processed aug_image_0189.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0189.jpg
# Processed aug_image_0190.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0190.jpg
# Processed aug_image_0191.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0191.jpg
# Processed aug_image_0192.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0192.jpg
# Processed aug_image_0193.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0193.jpg
# Processed aug_image_0194.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0194.jpg
# Processed aug_image_0195.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0195.jpg
# Processed aug_image_0196.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0196.jpg
# Processed aug_image_0197.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0197.jpg
# Processed aug_image_0198.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0198.jpg
# Processed aug_image_0199.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0199.jpg
# Processed aug_image_0200.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0200.jpg
# Processed aug_image_0201.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0201.jpg
# Processed aug_image_0202.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0202.jpg
# Processed aug_image_0203.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0203.jpg
# Processed aug_image_0204.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0204.jpg
# Processed aug_image_0205.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0205.jpg
# Processed aug_image_0206.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0206.jpg
# Processed aug_image_0207.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0207.jpg
# Processed aug_image_0208.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0208.jpg
# Processed aug_image_0209.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0209.jpg
# Processed aug_image_0210.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0210.jpg
# Processed aug_image_0211.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0211.jpg
# Processed aug_image_0212.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0212.jpg
# Processed aug_image_0213.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0213.jpg
# Processed aug_image_0214.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0214.jpg
# Processed aug_image_0215.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0215.jpg
# Processed aug_image_0216.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0216.jpg
# Processed aug_image_0217.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0217.jpg
# Processed aug_image_0218.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0218.jpg
# Processed aug_image_0219.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0219.jpg
# Processed aug_image_0220.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0220.jpg
# Processed aug_image_0221.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0221.jpg
# Processed aug_image_0222.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0222.jpg
# Processed aug_image_0223.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0223.jpg
# Processed aug_image_0224.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0224.jpg
# Processed aug_image_0225.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0225.jpg
# Processed aug_image_0226.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0226.jpg
# Processed aug_image_0227.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0227.jpg
# Processed aug_image_0228.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0228.jpg
# Processed aug_image_0229.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_
jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0305.jpg
# Processed aug_image_0306.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0306.jpg
# Processed aug_image_0307.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0307.jpg
# Processed aug_image_0308.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0308.jpg
# Processed aug_image_0309.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0309.jpg
# Processed aug_image_0310.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0310.jpg
# Processed aug_image_0311.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0311.jpg
# Processed aug_image_0312.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0312.jpg
# Processed aug_image_0313.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0313.jpg
# Processed aug_image_0314.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0314.jpg
# Processed aug_image_0315.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0315.jpg
# Processed aug_image_0316.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0316.jpg
# Processed aug_image_0317.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0317.jpg
# Processed aug_image_0318.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0318.jpg
# Processed aug_image_0319.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0319.jpg
# Processed aug_image_0320.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0320.jpg
# Processed aug_image_0321.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0321.jpg
# Processed aug_image_0322.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0322.jpg
# Processed aug_image_0323.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0323.jpg
# Processed aug_image_0324.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0324.jpg
# Processed aug_image_0325.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0325.jpg
# Processed aug_image_0326.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0326.jpg
# Processed aug_image_0327.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0327.jpg
# Processed aug_image_0328.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0328.jpg
# Processed aug_image_0329.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0329.jpg
# Processed aug_image_0330.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0330.jpg
# Processed aug_image_0331.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0331.jpg
# Processed aug_image_0332.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0332.jpg
# Processed aug_image_0333.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0333.jpg
# Processed aug_image_0334.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0334.jpg
# Processed aug_image_0335.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0335.jpg
# Processed aug_image_0336.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0336.jpg
# Processed aug_image_0337.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0337.jpg
# Processed aug_image_0338.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0338.jpg
# Processed aug_image_0339.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0339.jpg
# Processed aug_image_0340.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0340.jpg
# Processed aug_image_0341.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0341.jpg
# Processed aug_image_0342.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0342.jpg
# Processed aug_image_0343.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0343.jpg
# Processed aug_image_0344.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0344.jpg
# Processed aug_image_0345.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0345.jpg
# Processed aug_image_0346.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0346.jpg
# Processed aug_image_0347.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0347.jpg
# Processed aug_image_0348.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0348.jpg
# Processed aug_image_0349.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0349.jpg
# Processed aug_image_0350.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0350.jpg
# Processed aug_image_0351.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0351.jpg
# Processed aug_image_0352.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0352.jpg
# Processed aug_image_0353.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0353.jpg
# Processed aug_image_0354.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0354.jpg
# Processed aug_image_0355.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0355.jpg
# Processed aug_image_0356.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0356.jpg
# Processed aug_image_0357.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0357.jpg
# Processed aug_image_0358.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0358.jpg
# Processed aug_image_0359.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0359.jpg
# Processed aug_image_0360.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0360.jpg
# Processed aug_image_0361.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0361.jpg
# Processed aug_image_0362.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0362.jpg
# Processed aug_image_0363.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0363.jpg
# Processed aug_image_0364.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0364.jpg
# Processed aug_image_0365.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0365.jpg
# Processed aug_image_0366.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0366.jpg
# Processed aug_image_0367.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0367.jpg
# Processed aug_image_0368.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0368.jpg
# Processed aug_image_0369.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0369.jpg
# Processed aug_image_0370.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0370.jpg
# Processed aug_image_0371.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0371.jpg
# Processed aug_image_0372.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_0372.jpg
# ...
# Processed aug_image_2114.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2114.jpg
# Processed aug_image_2115.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2115.jpg
# Processed aug_image_2116.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2116.jpg
# Processed aug_image_2117.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2117.jpg
# Processed aug_image_2118.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2118.jpg
# Processed aug_image_2119.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2119.jpg
# Processed aug_image_2120.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2120.jpg
# Processed aug_image_2121.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2121.jpg
# Processed aug_image_2122.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_
jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2198.jpg
# Processed aug_image_2199.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2199.jpg
# Processed aug_image_2200.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2200.jpg
# Processed aug_image_2201.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2201.jpg
# Processed aug_image_2202.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2202.jpg
# Processed aug_image_2203.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2203.jpg
# Processed aug_image_2204.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2204.jpg
# Processed aug_image_2205.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2205.jpg
# Processed aug_image_2206.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2206.jpg
# Processed aug_image_2207.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2207.jpg
# Processed aug_image_2208.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2208.jpg
# Processed aug_image_2209.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2209.jpg
# Processed aug_image_2210.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2210.jpg
# Processed aug_image_2211.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2211.jpg
# Processed aug_image_2212.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2212.jpg
# Processed aug_image_2213.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2213.jpg
# Processed aug_image_2214.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2214.jpg
# Processed aug_image_2215.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2215.jpg
# Processed aug_image_2216.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2216.jpg
# Processed aug_image_2217.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2217.jpg
# Processed aug_image_2218.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2218.jpg
# Processed aug_image_2219.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2219.jpg
# Processed aug_image_2220.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2220.jpg
# Processed aug_image_2221.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2221.jpg
# Processed aug_image_2222.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2222.jpg
# Processed aug_image_2223.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2223.jpg
# Processed aug_image_2224.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2224.jpg
# Processed aug_image_2225.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2225.jpg
# Processed aug_image_2226.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2226.jpg
# Processed aug_image_2227.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2227.jpg
# Processed aug_image_2228.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2228.jpg
# Processed aug_image_2229.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2229.jpg
# Processed aug_image_2230.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2230.jpg
# Processed aug_image_2231.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2231.jpg
# Processed aug_image_2232.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2232.jpg
# Processed aug_image_2233.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2233.jpg
# Processed aug_image_2234.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2234.jpg
# Processed aug_image_2235.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2235.jpg
# Processed aug_image_2236.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2236.jpg
# Processed aug_image_2237.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2237.jpg
# Processed aug_image_2238.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2238.jpg
# Processed aug_image_2239.jpg and saved to /home/madhur/Projects/reflection_removal/model/dataset/predicted/aug_image_2239.jpg

# %%
def calculate_psnr(output_image, ground_truth_image):
    mse = np.mean((ground_truth_image - output_image) ** 2)
    if mse == 0:  
        return float('inf')
    max_pixel = 1.0  
    psnr_value = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr_value

def calculate_ssim(output_image, ground_truth_image):
    
    C1 = 0.01 ** 2
    C2 = 0.03 ** 2

    output_gray = cv2.cvtColor((output_image * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY).astype(np.float32) / 255.0
    ground_truth_gray = cv2.cvtColor((ground_truth_image * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY).astype(np.float32) / 255.0

    mu_x = cv2.GaussianBlur(output_gray, (11, 11), 1.5)
    mu_y = cv2.GaussianBlur(ground_truth_gray, (11, 11), 1.5)
    sigma_x = cv2.GaussianBlur(output_gray ** 2, (11, 11), 1.5) - mu_x ** 2
    sigma_y = cv2.GaussianBlur(ground_truth_gray ** 2, (11, 11), 1.5) - mu_y ** 2
    sigma_xy = cv2.GaussianBlur(output_gray * ground_truth_gray, (11, 11), 1.5) - mu_x * mu_y

    numerator = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
    denominator = (mu_x ** 2 + mu_y ** 2 + C1) * (sigma_x + sigma_y + C2)
    ssim_map = numerator / (denominator + 1e-6)
    return ssim_map.mean()

def calculate_precision_recall_accuracy(output_image, ground_truth_image):
    
    output_gray = cv2.cvtColor((output_image * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
    ground_truth_gray = cv2.cvtColor((ground_truth_image * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY)

    _, output_binary = cv2.threshold(output_gray, 128, 1, cv2.THRESH_BINARY)
    _, ground_truth_binary = cv2.threshold(ground_truth_gray, 128, 1, cv2.THRESH_BINARY)

    # calculate TP, FP, FN, TN
    tp = np.sum(output_binary * ground_truth_binary)  
    fp = np.sum(output_binary * (1 - ground_truth_binary)) 
    fn = np.sum((1 - output_binary) * ground_truth_binary)  
    tn = np.sum((1 - output_binary) * (1 - ground_truth_binary))  

    precision = tp / (tp + fp + 1e-6)  # avoid division by zero
    recall = tp / (tp + fn + 1e-6)
    accuracy = (tp + tn) / (tp + fp + fn + tn + 1e-6)

    return {"Precision": precision, "Recall": recall, "Accuracy": accuracy}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def test_model_on_directory(generator_path, test_dir, ground_truth_dir):
   
    generator = ReflectionRemovalNet().to(device)
    generator.load_state_dict(torch.load(generator_path, map_location=device))
    generator.eval()

    transform = transforms.Compose([
        transforms.ToTensor(),
    ])

    psnr_values = []
    ssim_values = []
    precision_values = []
    recall_values = []
    accuracy_values = []

    test_images = sorted(os.listdir(test_dir))
    ground_truth_images = sorted(os.listdir(ground_truth_dir))

    for test_img_name, gt_img_name in zip(test_images, ground_truth_images):
        test_img_path = os.path.join(test_dir, test_img_name)
        gt_img_path = os.path.join(ground_truth_dir, gt_img_name)

        input_image = Image.open(test_img_path).convert("RGB")
        input_tensor = transform(input_image).unsqueeze(0).to(device)

        with torch.no_grad():
            output_tensor = generator(input_tensor)

        output_tensor = output_tensor.squeeze(0).cpu().numpy()
        output_image = np.transpose(output_tensor, (1, 2, 0))
        output_image = np.clip(output_image, 0, 1)

        ground_truth_image = Image.open(gt_img_path).convert("RGB")
        ground_truth_image = np.asarray(ground_truth_image).astype(np.float32) / 255.0

        output_image = cv2.resize(output_image, (ground_truth_image.shape[1], ground_truth_image.shape[0]), interpolation=cv2.INTER_LINEAR)

        psnr_value = calculate_psnr(output_image, ground_truth_image)
        ssim_value = calculate_ssim(output_image, ground_truth_image)
        metrics = calculate_precision_recall_accuracy(output_image, ground_truth_image)

        psnr_values.append(psnr_value)
        ssim_values.append(ssim_value)
        precision_values.append(metrics["Precision"])
        recall_values.append(metrics["Recall"])
        accuracy_values.append(metrics["Accuracy"])

    avg_psnr = np.mean(psnr_values)
    avg_ssim = np.mean(ssim_values)
    avg_precision = np.mean(precision_values)
    avg_recall = np.mean(recall_values)
    avg_accuracy = np.mean(accuracy_values)

    print("Average Metrics for Directory:")
    print(f"PSNR: {avg_psnr:.4f}")
    print(f"SSIM: {avg_ssim:.4f}")
    print(f"Precision: {avg_precision:.4f}")
    print(f"Recall: {avg_recall:.4f}")
    print(f"Accuracy: {avg_accuracy:.4f}")

    return {
        "PSNR": avg_psnr,
        "SSIM": avg_ssim,
        "Precision": avg_precision,
        "Recall": avg_recall,
        "Accuracy": avg_accuracy,
    }

test_image_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_blended"
ground_truth_dir = r"/home/madhur/Projects/reflection_removal/model/dataset/aug_transmission_layer"
model_path = r"/home/madhur/Projects/reflection_removal/model/models/new_model_final.pth"

metrics = test_model_on_directory(model_path, test_image_dir, ground_truth_dir)
# Out:
# /tmp/ipykernel_121530/2995319999.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load(generator_path, map_location=device))
# Average Metrics for Directory:
# PSNR: 14.8833
# SSIM: 0.3387
# Precision: 0.7612
# Recall: 0.6793
# Accuracy: 0.7989
